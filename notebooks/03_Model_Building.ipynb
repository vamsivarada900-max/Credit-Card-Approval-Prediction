# %%
# ==========================================
# Import Required Libraries
# ==========================================

import pandas as pd
import numpy as np
import joblib

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Evaluation
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

import warnings
warnings.filterwarnings("ignore")

print("Libraries Imported Successfully!")
# Out:
# Libraries Imported Successfully!

# %%
# ==========================================
# Load Processed Dataset
# ==========================================

data = pd.read_csv('/content/processed_credit_card_data.csv')

print("Dataset Loaded Successfully!")
print("Dataset Shape:", data.shape)
# Out:
# Dataset Loaded Successfully!
# Dataset Shape: (36457, 18)

# %%
X = data.drop("TARGET", axis=1)
y = data["TARGET"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
X = data.drop("TARGET", axis=1)
y = data["TARGET"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Logistic Regression

# %%
 # ==========================================
# Logistic Regression
# ==========================================

lr_model = LogisticRegression(
    random_state=42,
    max_iter=1000
)

lr_model.fit(X_train_scaled, y_train)

lr_predictions = lr_model.predict(X_test_scaled)

lr_accuracy = accuracy_score(y_test, lr_predictions)
lr_precision = precision_score(y_test, lr_predictions)
lr_recall = recall_score(y_test, lr_predictions)
lr_f1 = f1_score(y_test, lr_predictions)
lr_auc = roc_auc_score(y_test, lr_predictions)

print("Accuracy :", lr_accuracy)
print("Precision:", lr_precision)
print("Recall   :", lr_recall)
print("F1 Score :", lr_f1)
print("ROC-AUC  :", lr_auc)
# Out:
# Accuracy : 0.9831321996708722
# Precision: 0.0
# Recall   : 0.0
# F1 Score : 0.0
# ROC-AUC  : 0.5

# %% [markdown]
# Decision Tree

# %%
# ==========================================
# Decision Tree
# ==========================================

dt_model = DecisionTreeClassifier(
    random_state=42,
    class_weight="balanced",
    max_depth=8,
    min_samples_leaf=10
)
dt_model.fit(X_train_scaled, y_train)

dt_predictions = dt_model.predict(X_test_scaled)

dt_accuracy = accuracy_score(y_test, dt_predictions)
dt_precision = precision_score(y_test, dt_predictions)
dt_recall = recall_score(y_test, dt_predictions)
dt_f1 = f1_score(y_test, dt_predictions)
dt_auc = roc_auc_score(y_test, dt_predictions)

print("Accuracy :", dt_accuracy)
print("Precision:", dt_precision)
print("Recall   :", dt_recall)
print("F1 Score :", dt_f1)
print("ROC-AUC  :", dt_auc)
# Out:
# Accuracy : 0.4832693362589139
# Precision: 0.01874834961711117
# Recall   : 0.5772357723577236
# F1 Score : 0.03631713554987212
# ROC-AUC  : 0.5294464536220198

# %% [markdown]
# Random Forest

# %%
# ==========================================
# Random Forest
# ==========================================

rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train_scaled, y_train)

rf_predictions = rf_model.predict(X_test_scaled)

rf_accuracy = accuracy_score(y_test, rf_predictions)
rf_precision = precision_score(y_test, rf_predictions)
rf_recall = recall_score(y_test, rf_predictions)
rf_f1 = f1_score(y_test, rf_predictions)
rf_auc = roc_auc_score(y_test, rf_predictions)

print("Accuracy :", rf_accuracy)
print("Precision:", rf_precision)
print("Recall   :", rf_recall)
print("F1 Score :", rf_f1)
print("ROC-AUC  :", rf_auc)
# Out:
# Accuracy : 0.9809380142622052
# Precision: 0.35185185185185186
# Recall   : 0.15447154471544716
# F1 Score : 0.21468926553672316
# ROC-AUC  : 0.574794706658184

# %% [markdown]
# XGBoost

# %%
# !pip install xgboost -q

# %%
from xgboost import XGBClassifier

# %%
# ==========================================
# XGBoost
# ==========================================

xgb_model = XGBClassifier(
    random_state=42,
    eval_metric='logloss'
)

xgb_model.fit(X_train_scaled, y_train)

xgb_predictions = xgb_model.predict(X_test_scaled)

xgb_accuracy = accuracy_score(y_test, xgb_predictions)
xgb_precision = precision_score(y_test, xgb_predictions)
xgb_recall = recall_score(y_test, xgb_predictions)
xgb_f1 = f1_score(y_test, xgb_predictions)
xgb_auc = roc_auc_score(y_test, xgb_predictions)

print("Accuracy :", xgb_accuracy)
print("Precision:", xgb_precision)
print("Recall   :", xgb_recall)
print("F1 Score :", xgb_f1)
print("ROC-AUC  :", xgb_auc)
# Out:
# Accuracy : 0.981897970378497
# Precision: 0.3548387096774194
# Recall   : 0.08943089430894309
# F1 Score : 0.14285714285714285
# ROC-AUC  : 0.5433205524690203

# %% [markdown]
# Model Comparison

# %%
comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "XGBoost"
    ],
    "Accuracy": [
        lr_accuracy,
        dt_accuracy,
        rf_accuracy,
        xgb_accuracy
    ],
    "Precision": [
        lr_precision,
        dt_precision,
        rf_precision,
        xgb_precision
    ],
    "Recall": [
        lr_recall,
        dt_recall,
        rf_recall,
        xgb_recall
    ],
    "F1 Score": [
        lr_f1,
        dt_f1,
        rf_f1,
        xgb_f1
    ],
    "ROC-AUC": [
        lr_auc,
        dt_auc,
        rf_auc,
        xgb_auc
    ]
})

comparison = comparison.sort_values(
    by="F1 Score",
    ascending=False
)

comparison
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 2        Random Forest  0.980938   0.351852  0.154472  0.214689  0.574795
# 3              XGBoost  0.981898   0.354839  0.089431  0.142857  0.543321
# 1        Decision Tree  0.483269   0.018748  0.577236  0.036317  0.529446
# 0  Logistic Regression  0.983132   0.000000  0.000000  0.000000  0.500000

# %%
models = {
    "Logistic Regression": lr_model,
    "Decision Tree": dt_model,
    "Random Forest": rf_model,
    "XGBoost": xgb_model
}

best_model_name = comparison.iloc[0]["Model"]

best_model = models[best_model_name]

print("Best Model:", best_model_name)
# Out:
# Best Model: Random Forest

# %%
import joblib

joblib.dump(best_model, "model.pkl")
joblib.dump(scaler, "scaler.pkl")

print("Model, scaler, and encoders saved successfully!")
# Out:
# Model, scaler, and encoders saved successfully!

# %%
X = data.drop("TARGET", axis=1)
print(X.columns.tolist())
# Out:
# ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'AGE', 'EMPLOYMENT_YEARS']

# %%
print(classification_report(y_test, dt_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.48      0.65      7169
#            1       0.02      0.58      0.04       123
#
#     accuracy                           0.48      7292
#    macro avg       0.50      0.53      0.34      7292
# weighted avg       0.97      0.48      0.64      7292

# %%
# Find some rejected predictions from the test set

pred = best_model.predict(X_test_scaled)

rejected = X_test[pred == 1]

print("Number of rejected predictions:", len(rejected))

rejected.head(10)
# Out:
# Number of rejected predictions: 54
#        CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 36150            0             0                1             0
# 31723            1             0                1             0
# 35174            0             0                1             0
# 22581            1             1                1             2
# 28513            0             0                1             0
# 11062            1             0                1             1
# 36388            0             0                0             0
# 36239            1             1                1             1
# 33572            1             0                0             1
# 29582            0             1                0             0
#
#        AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 36150          216000.0                 1                    4
# 31723          112500.0                 0                    1
# 35174          180000.0                 4                    4
# 22581          247500.0                 4                    4
# 28513          180000.0                 1                    4
# 11062          180000.0                 4                    3
# 36388          112500.0                 1                    4
# 36239          135000.0                 4                    1
# 33572          360000.0                 4                    1
# 29582          135000.0                 4                    2
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 36150                   4                  1           1                0
# 31723                   1                  1           1                0
# 35174                   0                  1           1                0
# 22581                   1                  1           1                0
# 28513                   1                  1           1                0
# 11062                   1                  1           1                1
# 36388                   3                  2           1                0
# 36239                   3                  1           1                0
# 33572                   1                  1           1                1
# 29582                   0                  1           1                1
#
#        FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  AGE  \
# 36150           0           0               17              1.0   54
# 31723           0           0               16              2.0   55
# 35174           0           0                8              2.0   54
# 22581           0           0                8              4.0   47
# 28513           0           0               17              2.0   62
# 11062           0           0               17              3.0   28
# 36388           0           0               17              2.0   58
# 36239           0           0               10              3.0   51
# 33572           1           0               10              3.0   30
# 29582           0           0               14              2.0   27
#
#        EMPLOYMENT_YEARS
# 36150          5.457534
# 31723          1.520548
# 35174          9.884932
# 22581          1.465753
# 28513          5.457534
# 11062          4.635616
# 36388          5.457534
# 36239         17.421918
# 33572          1.284932
# 29582          0.600000

# %%
original_rejected = X_test.loc[rejected.index]

original_rejected.head()
# Out:
#        CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 36150            0             0                1             0
# 31723            1             0                1             0
# 35174            0             0                1             0
# 22581            1             1                1             2
# 28513            0             0                1             0
#
#        AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 36150          216000.0                 1                    4
# 31723          112500.0                 0                    1
# 35174          180000.0                 4                    4
# 22581          247500.0                 4                    4
# 28513          180000.0                 1                    4
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 36150                   4                  1           1                0
# 31723                   1                  1           1                0
# 35174                   0                  1           1                0
# 22581                   1                  1           1                0
# 28513                   1                  1           1                0
#
#        FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  AGE  \
# 36150           0           0               17              1.0   54
# 31723           0           0               16              2.0   55
# 35174           0           0                8              2.0   54
# 22581           0           0                8              4.0   47
# 28513           0           0               17              2.0   62
#
#        EMPLOYMENT_YEARS
# 36150          5.457534
# 31723          1.520548
# 35174          9.884932
# 22581          1.465753
# 28513          5.457534

# %%
pd.set_option('display.max_columns', None)

original_rejected.head(1)
# Out:
#        CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 36150            0             0                1             0
#
#        AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 36150          216000.0                 1                    4
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 36150                   4                  1           1                0
#
#        FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  AGE  \
# 36150           0           0               17              1.0   54
#
#        EMPLOYMENT_YEARS
# 36150          5.457534

# %%
# Reload the processed dataset before train-test split
data = pd.read_csv("/content/processed_credit_card_data.csv")

# Show the original row using its index
print(data.loc[36150])
# Out:
# CODE_GENDER                 0.000000
# FLAG_OWN_CAR                0.000000
# FLAG_OWN_REALTY             1.000000
# CNT_CHILDREN                0.000000
# AMT_INCOME_TOTAL       216000.000000
# NAME_INCOME_TYPE            1.000000
# NAME_EDUCATION_TYPE         4.000000
# NAME_FAMILY_STATUS          4.000000
# NAME_HOUSING_TYPE           1.000000
# FLAG_MOBIL                  1.000000
# FLAG_WORK_PHONE             0.000000
# FLAG_PHONE                  0.000000
# FLAG_EMAIL                  0.000000
# OCCUPATION_TYPE            17.000000
# CNT_FAM_MEMBERS             1.000000
# TARGET                      1.000000
# AGE                        54.000000
# EMPLOYMENT_YEARS            5.457534
# Name: 36150, dtype: float64

# %%
import joblib

joblib.dump(best_model, "model.pkl")
joblib.dump(scaler, "scaler.pkl")

print("Files saved successfully!")
# Out:
# Files saved successfully!

# %%
print(best_model)
# Out:
# RandomForestClassifier(random_state=42)
